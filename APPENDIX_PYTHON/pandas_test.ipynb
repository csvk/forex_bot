# %%
import pandas as pd
import json

# %%
df = pd.read_json("iris.json")

# %%
df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepalLength  150 non-null    float64
#  1   sepalWidth   150 non-null    float64
#  2   petalLength  150 non-null    float64
#  3   petalWidth   150 non-null    float64
#  4   species      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
list(df.species.unique())
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 0          5.1         3.5          1.4         0.2  setosa  17.85   0.28
# 1          4.9         3.0          1.4         0.2  setosa  14.70   0.28
# 2          4.7         3.2          1.3         0.2  setosa  15.04   0.26
# 3          4.6         3.1          1.5         0.2  setosa  14.26   0.30
# 4          5.0         3.6          1.4         0.2  setosa  18.00   0.28
#
#    longSepal
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False

# %%
df['calc'] = df.sepalLength * df.sepalWidth

# %%
ownser = df.petalLength * df.petalWidth

# %%
df['calc2'] = ownser

# %%
df['longSepal'] = [True if x > 5.0 else False for x in df.sepalLength]

# %%
df.longSepal.value_counts()
# Out:
# True     118
# False     32
# Name: longSepal, dtype: int64

# %%
# .iloc .loc

# %%
df_temp = df.iloc[4:10].copy()

# %%
df.head(10)
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 0          5.1         3.5          1.4         0.2  setosa  17.85   0.28
# 1          4.9         3.0          1.4         0.2  setosa  14.70   0.28
# 2          4.7         3.2          1.3         0.2  setosa  15.04   0.26
# 3          4.6         3.1          1.5         0.2  setosa  14.26   0.30
# 4          5.0         3.6          1.4         0.2  setosa  18.00   0.28
# 5          5.4         3.9          1.7         0.4  setosa  21.06   0.68
# 6          4.6         3.4          1.4         0.3  setosa  15.64   0.42
# 7          5.0         3.4          1.5         0.2  setosa  17.00   0.30
# 8          4.4         2.9          1.4         0.2  setosa  12.76   0.28
# 9          4.9         3.1          1.5         0.1  setosa  15.19   0.15
#
#    longSepal
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# ...

# %%
df_temp.head(6)
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 4          5.0         3.6          1.4         0.2  setosa  18.00   0.28
# 5          5.4         3.9          1.7         0.4  setosa  21.06   0.68
# 6          4.6         3.4          1.4         0.3  setosa  15.64   0.42
# 7          5.0         3.4          1.5         0.2  setosa  17.00   0.30
# 8          4.4         2.9          1.4         0.2  setosa  12.76   0.28
# 9          4.9         3.1          1.5         0.1  setosa  15.19   0.15
#
#    longSepal
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False

# %%
df_temp.iloc[0:3]
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 4          5.0         3.6          1.4         0.2  setosa  18.00   0.28
# 5          5.4         3.9          1.7         0.4  setosa  21.06   0.68
# 6          4.6         3.4          1.4         0.3  setosa  15.64   0.42
#
#    longSepal
# 4      False
# 5       True
# 6      False

# %%
df_temp.loc[6:12]
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 6          4.6         3.4          1.4         0.3  setosa  15.64   0.42
# 7          5.0         3.4          1.5         0.2  setosa  17.00   0.30
# 8          4.4         2.9          1.4         0.2  setosa  12.76   0.28
# 9          4.9         3.1          1.5         0.1  setosa  15.19   0.15
#
#    longSepal
# 6      False
# 7      False
# 8      False
# 9      False

# %%
df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 0          5.1         3.5          1.4         0.2  setosa  17.85   0.28
# 1          4.9         3.0          1.4         0.2  setosa  14.70   0.28
# 2          4.7         3.2          1.3         0.2  setosa  15.04   0.26
# 3          4.6         3.1          1.5         0.2  setosa  14.26   0.30
# 4          5.0         3.6          1.4         0.2  setosa  18.00   0.28
#
#    longSepal
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False

# %%
df_sub = df[(df.sepalLength < 4.9)&(df.sepalWidth > 3.5)].copy()

# %%
df_sub
# Out:
#     sepalLength  sepalWidth  petalLength  petalWidth species   calc  calc2  \
# 22          4.6         3.6          1.0         0.2  setosa  16.56    0.2
#
#     longSepal
# 22      False

# %%
list(df.columns)
# Out:
# ['sepalLength',
#  'sepalWidth',
#  'petalLength',
#  'petalWidth',
#  'species',
#  'calc',
#  'calc2',
#  'longSepal']

# %%
cols = ['species','sepalLength']
df_slim = df[cols].copy()

# %%
df_slim.head()
# Out:
#      species  sepalLength
# 0  virginica          4.9
# 1  virginica          5.6
# 2  virginica          5.7
# 3  virginica          5.8
# 4  virginica          5.8

# %%
df_slim.sort_values(by=['species', 'sepalLength'], ascending=[False, True], inplace=True)

# %%
df_slim.reset_index(drop=True, inplace=True)

# %%
df_slim.to_pickle("df_slim.pkl")

# %%
dfn = pd.read_pickle("df_slim.pkl")

# %%
dfn
# Out:
#        species  sepalLength
# 0    virginica          4.9
# 1    virginica          5.6
# 2    virginica          5.7
# 3    virginica          5.8
# 4    virginica          5.8
# ..         ...          ...
# 145     setosa          5.5
# 146     setosa          5.5
# 147     setosa          5.7
# 148     setosa          5.7
# 149     setosa          5.8
#
# [150 rows x 2 columns]
